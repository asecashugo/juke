# %%
import controls

# %%
controls.get_state()

# %%
controls.volume(volume_perc=1)

# %%
controls.play(uri="spotify:playlist:6ExayMSjKKwQKdORILlKYA")

# %%
controls.play_playlist(list_name='hercules')

# %%
controls.pause()

# %%
controls.toggle()

# %%
controls.stop()

# %%
controls.next()

# %%
controls.play(uri="music-library/INTERNAL/listo.mp3")

# %%
# Get the current playback queue
controls.get_queue()

# %%
# Add a track to the queue
controls.add_to_queue(uri="music-library/INTERNAL/listo.mp3")

# %%
controls.browse()
