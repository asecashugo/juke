# %%
import controls

# %%
controls.get_state()
# Out:
# '{"status":"stop","position":0,"title":"Cold Heart - PNAU Remix","artist":"Elton John","album":"The Lockdown Sessions","albumart":"https://i.scdn.co/image/ab67616d0000b273eb842acacb3238b2bf3b8471","uri":"spotify:track:6JIC3hbC28JZKZ8AlAqX8h","trackType":"spotify","codec":"ogg","seek":254,"duration":202,"samplerate":"320 kbps","bitdepth":"16 bit","channels":2,"random":null,"repeat":null,"repeatSingle":false,"consume":false,"volume":43,"dbVolume":null,"disableVolumeControl":false,"mute":false,"stream":"spotify","volatile":false,"service":"spop"}'

# %%
controls.volume(volume_perc==10)

# %%
controls.play()

# %%
controls.pause()

# %%
controls.toggle()

# %%
controls.stop()

# %%
controls.next()
